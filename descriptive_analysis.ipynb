# %% [markdown]
# ## Amazon Cosumer Behaviour Dataset
#
# This notebook is focused exploring the data through descriptive analysis.
# Previously step was understading the dataset, and the following Next step is transforming the data.
#
# Link to Kaggle: https://www.kaggle.com/datasets/swathiunnikrishnan/amazon-consumer-behaviour-dataset

# %% [markdown]
# ##### Data Dictionary:
#
# - 1.age= age
# - 2.gender= gender
# - 3.Purchase_Frequency= How frequently do you make purchases on Amazon?
# - 4.Purchase_Categories= What product categories do you typically purchase on Amazon?
# - 5.Personalized_Recommendation_Frequency = Have you ever made a purchase based on personalized product recommendations from Amazon?
# - 6.Browsing_Frequency =How often do you browse Amazon's website or app?
# - 7.Product_Search_Method =How do you search for products on Amazon?
# - 8.Search_Result_Exploration =Do you tend to explore multiple pages of search results or focus on the first page?
# - 9.Customer_Reviews_Importance =How important are customer reviews in your decision-making process?
# - 10.Add_to_Cart_Browsing =Do you add products to your cart while browsing on Amazon?
# - 11.Cart_Completion_Frequency =How often do you complete the purchase after adding products to your cart?
# - 12.Cart_Abandonment_Factors =What factors influence your decision to abandon a purchase in your cart?
# - 13.Saveforlater_Frequency =Do you use Amazon's "Save for Later" feature, and if so, how often?
# - 14.Review_Left =Have you ever left a product review on Amazon?
# - 15.Review_Reliability =How much do you rely on product reviews when making a purchase?
# - 16.Review_Helpfulness =Do you find helpful information from other customers' reviews?
# - 17.Personalized_Recommendation_Frequency =How often do you receive personalized product recommendations from Amazon?
# - 18.Recommendation_Helpfulness =Do you find the recommendations helpful?
# - 19.Rating_Accuracy =How would you rate the relevance and accuracy of the recommendations you receive?
# - 20.Shopping_Satisfaction =How satisfied are you with your overall shopping experience on Amazon?
# - 23.Service_Appreciation =What aspects of Amazon's services do you appreciate the most?
# - 24.Improvement_Areas =Are there any areas where you think Amazon can improve?

# %% [markdown]
# On this part of the study, we are going to apply some descriptive and multivariate techniques to further understand the behaviour of the elements, as well of the variables.

# %%
# Importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Importing dataset

df = pd.read_csv('archive/Amazon Customer Behavior Survey.csv')

# %%
df.head(2)
# Out:
#                         Timestamp  age  Gender Purchase_Frequency  \
# 0  2023/06/04 1:28:19 PM GMT+5:30   23  Female  Few times a month
# 1  2023/06/04 2:30:44 PM GMT+5:30   23  Female       Once a month
#
#         Purchase_Categories Personalized_Recommendation_Frequency  \
# 0  Beauty and Personal Care                                   Yes
# 1      Clothing and Fashion                                   Yes
#
#   Browsing_Frequency Product_Search_Method Search_Result_Exploration  \
# 0   Few times a week               Keyword            Multiple pages
# 1  Few times a month               Keyword            Multiple pages
#
#    Customer_Reviews_Importance  ... Saveforlater_Frequency Review_Left  \
# 0                            1  ...              Sometimes         Yes
# 1                            1  ...                 Rarely          No
#
#   Review_Reliability Review_Helpfulness  \
# 0       Occasionally                Yes
# 1            Heavily                Yes
#
#   Personalized_Recommendation_Frequency  Recommendation_Helpfulness  \
# 0                                      2                        Yes
# 1                                      2                  Sometimes
#
#   Rating_Accuracy   Shopping_Satisfaction    Service_Appreciation  \
# 0                1                      1      Competitive prices
# 1                3                      2  Wide product selection
#
#           Improvement_Areas
# 0  Reducing packaging waste
# 1  Reducing packaging waste
#
# [2 rows x 23 columns]

# %% [markdown]
# First, we are going to plot some metrics about the numerical values on the dataset. Here, we are analyzing the mean, standard deviation, min value, 25/50/75 percentil and max value.

# %%
# Dataset descriptive values

df.describe().T
# Out:
#                                         count       mean        std  min  \
# age                                     602.0  30.790698  10.193276  3.0
# Customer_Reviews_Importance             602.0   2.480066   1.185226  1.0
# Personalized_Recommendation_Frequency   602.0   2.699336   1.042028  1.0
# Rating_Accuracy                         602.0   2.672757   0.899744  1.0
# Shopping_Satisfaction                   602.0   2.463455   1.012152  1.0
#
#                                          25%   50%   75%   max
# age                                     23.0  26.0  36.0  67.0
# Customer_Reviews_Importance              1.0   3.0   3.0   5.0
# Personalized_Recommendation_Frequency    2.0   3.0   3.0   5.0
# Rating_Accuracy                          2.0   3.0   3.0   5.0
# Shopping_Satisfaction                    2.0   2.0   3.0   5.0

# %% [markdown]
# - The average age of survey respondants was around 30 years old, where 75% of the population was up to 36 yo;
# - The scale of the dimensions Customer_Reviews_Importance, Personalized_Recommendation_Frequency, Rating_Accuracy and Shopping_Satisfaction is 1 to 5, but the mean value was around the average for every dimension;
# - Shopping_Satisfaction got the worst performance, where 50% of population awnsered below 3.
#
# Let's showcase a distribution plot to further understand the behaviour of these variables.

# %%
# Plotting bar plots for categorical dimensions

categorical_dimensions = ['Purchase_Frequency', 
                          'Personalized_Recommendation_Frequency', 
                          'Browsing_Frequency', 
                          'Saveforlater_Frequency', 
                          'Review_Reliability', 
                          'Recommendation_Helpfulness', 
                          'Review_Helpfulness',
                          'Search_Result_Exploration', 
                          'Service_Appreciation'
                          ]

for dimension in categorical_dimensions:
    # Figure size
    fig, ax = plt.subplots(figsize =(16, 6))
    
    # Declaring axis    
    keys = df[dimension].unique()
    values = df[dimension].value_counts()
    
    # Remove x, y Ticks
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    
    # Remove axes splines
    for s in ['top', 'bottom', 'left', 'right']:
        ax.spines[s].set_visible(False)
        
    # Setting title
    ax.set_title('Bar plot for dimension ' + dimension, loc ='left', )
    
    # Show top values
    ax.invert_yaxis()
    
    # Showcasing the result
    plt.barh(keys, values)
    plt.show()
