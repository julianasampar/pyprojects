# %% [markdown]
# ## Building an Agent with Claude API
# Testing Vision and PDF functionalities

# %%
# Import libraries

import sys
import importlib
from anthropic import Anthropic
from dotenv import load_dotenv

# %%
# Loading Anthropic API Key
load_dotenv()

# Getting chatbot_agent
sys.path.append("/Users/julianasampar/Desktop/learning_dev/personal_dev/pyprojects/claude")
from agents.chatbot_agent import interlocutor

importlib.reload(interlocutor)
# Out:
# <module 'agents.chatbot_agent.interlocutor' from '/Users/julianasampar/Desktop/learning_dev/personal_dev/pyprojects/claude/agents/chatbot_agent/interlocutor.py'>

# %%
# Create an API Client
client = Anthropic()

# Defining parameters
model = "claude-haiku-4-5"
max_tokens=1000

# %%
messages=[]
interlocutor.chat(messages=messages)
# Out:
# Hey there! 👋 How's it going? What can I help you with?Haha, glad I'm up and running for you! 🎉 Sometimes these things can be finicky. What's on your mind? I'm here to help with whatever you need!

# %%
print("Messages being sent:")
print(messages)
print("Length:", len(messages))
# Out:
# Messages being sent:
# [{'role': 'user', 'content': 'Hey!!!'}, {'role': 'assistant', 'content': [ParsedTextBlock(citations=None, text="Hey there! 👋 How's it going? What can I help you with?", type='text', parsed_output=None)]}, {'role': 'user', 'content': 'Oh I finally was able to make you work, thank god!'}, {'role': 'assistant', 'content': [ParsedTextBlock(citations=None, text="Haha, glad I'm up and running for you! 🎉 Sometimes these things can be finicky. What's on your mind? I'm here to help with whatever you need!", type='text', parsed_output=None)]}]
# Length: 4

# %%
from pydantic import Field
from mcp.server.fastmcp import FastMCP
mcp = FastMCP("mcp_blabla", log_level="ERROR")

# %%
@mcp.tool(
    name="blablabla",
    description="Blablabla"
)
def blablabla(
    bla: int = Field(description="blabla")
):
    return bla
